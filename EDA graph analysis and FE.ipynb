# %%
print ("ram")
# Out:
# ram

# %%
import pandas as pd

# %%
cln_data = pd.read_csv("https://raw.githubusercontent.com/Ramachandran-D/EDA-basics-files-/refs/heads/main/Cleaned_google_playstore_analysis_CSV.csv")

# %%
cln_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews    Size  Installs  Type  Price Content Rating  \
# 0      159   19000     10000  Free    0.0       Everyone
# 1      967   14000    500000  Free    0.0       Everyone
# 2    87510  8.7000   5000000  Free    0.0       Everyone
# 3   215644   25000  50000000  Free    0.0           Teen
# 4      967  2.8000    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
cln_data['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'np.nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
import numpy as np
cln_data['Size'].str.replace("np.nan", str(np.nan))
# Out:
# 0         19000
# 1         14000
# 2        8.7000
# 3         25000
# 4        2.8000
#           ...
# 10835     53000
# 10836    3.6000
# 10837    9.5000
# 10838       nan
# 10839     19000
# Name: Size, Length: 10840, dtype: object

# %%
cln_data['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'np.nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings 

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
cln_data.shape
# Out:
# (10840, 16)

# %%
cln_data[cln_data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
cln_data[cln_data.duplicated('App')]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#          Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
cln_data = cln_data.drop_duplicates(subset=['App'], keep='first')

# %%
cln_data[cln_data.duplicated('App')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
cln_data.shape
# Out:
# (9659, 16)

# %%
numerical_feature = [feature for feature in cln_data.columns if cln_data[feature].dtype != 'O']

# %%
catagorical_feature = [feature for feature in cln_data.columns if cln_data[feature].dtype == 'O']

# %%
numerical_feature
# Out:
# ['Rating', 'Reviews', 'Installs', 'Price', 'day', 'month', 'year']

# %%
catagorical_feature
# Out:
# ['App',
#  'Category',
#  'Size',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
cln_data[numerical_feature]
# Out:
#        Rating  Reviews  Installs  Price  day  month  year
# 0         4.1      159     10000    0.0    7      1  2018
# 1         3.9      967    500000    0.0   15      1  2018
# 2         4.7    87510   5000000    0.0    1      8  2018
# 3         4.5   215644  50000000    0.0    8      6  2018
# 4         4.3      967    100000    0.0   20      6  2018
# ...       ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38      5000    0.0   25      7  2017
# 10836     5.0        4       100    0.0    6      7  2018
# 10837     NaN        3      1000    0.0   20      1  2017
# 10838     4.5      114      1000    0.0   19      1  2015
# 10839     4.5   398307  10000000    0.0   25      7  2018
#
# [9659 rows x 7 columns]

# %%
cln_data['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10835    Free
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# Name: Type, Length: 9659, dtype: object

# %%
cln_data['Type'].value_counts()
# Out:
# Type
# Free    8902
# Paid     756
# Name: count, dtype: int64

# %%
cln_data['Type'].value_counts(normalize = True)
# Out:
# Type
# Free    0.921723
# Paid    0.078277
# Name: proportion, dtype: float64

# %%
cln_data['Type'].value_counts(normalize = True)*100
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
#to catagorise th data 
for col in catagorical_feature:
    print (f"{col}:{cln_data[col].value_counts(normalize = True)*100}")
    print("=========================================================")
# Out:
# App:App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: proportion, Length: 9659, dtype: float64
# ...
# Category:Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
sns.countplot(x  = cln_data['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
numerical_feature
# Out:
# ['Rating', 'Reviews', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(cln_data['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(cln_data['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
plt.Figure(figsize=(15,15))
plt.suptitle("UNIVARIENT ANALYSIS OF NUMERICAL FEATURES",fontsize = 20, fontweight = 'bold', alpha =0.8,y=1)
for i in range (0, len(numerical_feature)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=cln_data[numerical_feature[i]],shade = True, color='r')
    plt.xlabel(numerical_feature[i])
    plt.tight_layout()

# %%
catagorical_feature
# Out:
# ['App',
#  'Category',
#  'Size',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
cln_data["Category"].value_counts().plot.pie(figsize=(15,15))
# Out:
# <Axes: ylabel='count'>

# %%
cln_data["Category"].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
#get only top 10 catagory 
cln_data["Category"].value_counts()[:10].plot.pie(figsize=(5,5))
# Out:
# <Axes: ylabel='count'>

# %%
cln_data.groupby(['Category', 'App'])['Installs']

# %%
cln_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews    Size  Installs  Type  Price Content Rating  \
# 0      159   19000     10000  Free    0.0       Everyone
# 1      967   14000    500000  Free    0.0       Everyone
# 2    87510  8.7000   5000000  Free    0.0       Everyone
# 3   215644   25000  50000000  Free    0.0           Teen
# 4      967  2.8000    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
data_grp = cln_data.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
data_grp.sort_values('Installs', ascending=False)
# Out:
#                 Category                            App    Installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9275    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 6020             MEDICAL                   EP Cook Book           0
# 3662             FINANCE                    Eu sou Rico           0
# 1797              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 6471  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
cln_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews    Size  Installs  Type  Price Content Rating  \
# 0      159   19000     10000  Free    0.0       Everyone
# 1      967   14000    500000  Free    0.0       Everyone
# 2    87510  8.7000   5000000  Free    0.0       Everyone
# 3   215644   25000  50000000  Free    0.0           Teen
# 4      967  2.8000    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#the app which is only having 5 ratings
cln_data.groupby(['App'])['Rating']

# %%
rating = cln_data.groupby(['App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating
# Out:
#                                                    App  Rating
# 0                            Comunidad De Fe Minitries     5.0
# 1                                      Tablet Reminder     5.0
# 2                                Noticias FC Barcelona     5.0
# 3     Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                    DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 9654                              DK Childcare Centers     0.0
# 9655                         Pediatric Emergency Guide     0.0
# 9656                                     Pekalongan CJ     0.0
# 9657                        Penn State Health OnDemand     0.0
# 9658              "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
rating.Rating == 5.0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# Name: Rating, Length: 9659, dtype: bool

# %%
rating[rating.Rating == 5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
cln_data.groupby('Category').agg({'Installs' :'sum', 'Reviews':'sum'}) #agg is aggregate
# Out:
#                         Installs    Reviews
# Category
# ART_AND_DESIGN         114338100    1419203
# AUTO_AND_VEHICLES       53130211    1163666
# BEAUTY                  27197050     396240
# BOOKS_AND_REFERENCE   1665969576   16721314
# BUSINESS               697164865    9890245
# COMICS                  44981150    2342071
# COMMUNICATION        11038276251  285811368
# DATING                 140926107    3623544
# EDUCATION              352952000   13364148
# ENTERTAINMENT         2113660000   34762650
# EVENTS                  15973161     161018
# FAMILY                4427941505  143825488
# FINANCE                455348734   12662106
# FOOD_AND_DRINK         211798751    6325028
# GAME                 13878924415  622298709
# HEALTH_AND_FITNESS    1144022512   21361355
# HOUSE_AND_HOME          97212461    1929847
# LIBRARIES_AND_DEMO      52995910     906831
# LIFESTYLE              503823539   11832671
# MAPS_AND_NAVIGATION    503281890   17729148
# ...

# %%
cln_data.groupby('Category').agg({'Installs' :'sum', 'Reviews':'sum'}).reset_index()
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
plt.Figure(figsize=(10,10))
sns.boxplot(x='Installs', y ='Rating', data = cln_data)
plt.xticks(size =15,rotation = 10)
plt.show()
